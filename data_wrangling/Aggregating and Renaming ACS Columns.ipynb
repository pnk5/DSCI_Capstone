# %%
# Input:  “complete_everything.csv”
# Does: renames all census columns and only keeps final needed columns of the data set
# Output: “clean_columns_everything.csv”

library("data.table")
#setwd('/data_source')
install.packages('bit64')
data <- fread("complete_everything.csv")
# Out:
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
#aggregating/renaming census columns
library('dplyr')
#1
data$total_pop = data$AJWME001 
#2
data$percent_male = 100*data$AJWBE002/data$AJWBE001
#3
data$percent_0to19_years = 100*(data$AJWBE003 + data$AJWBE004 + data$AJWBE005 + data$AJWBE006 + data$AJWBE007 + data$AJWBE027 + data$AJWBE028 + data$AJWBE029 + data$AJWBE030 + data$AJWBE031)/data$AJWBE001 
#4
data$percent_20to39_years = 100*(data$AJWBE008 + data$AJWBE009 + data$AJWBE010 + data$AJWBE011 + data$AJWBE012 + data$AJWBE013 + data$AJWBE032 + data$AJWBE033 + data$AJWBE034 + data$AJWBE035 + data$AJWBE036 + data$AJWBE037)/data$AJWBE001 
#5
data$percent_40to64_years = 100*(data$AJWBE014 + data$AJWBE015 + data$AJWBE016 + data$AJWBE017 + data$AJWBE018 + data$AJWBE019 + data$AJWBE038 + data$AJWBE039 + data$AJWBE040 + data$AJWBE041 + data$AJWBE042 + data$AJWBE043)/data$AJWBE001 
#6
data$percent_65andover = 100*(data$AJWBE020 + data$AJWBE021 + data$AJWBE022 + data$AJWBE023 + data$AJWBE024 + data$AJWBE025 + data$AJWBE044 + data$AJWBE045 + data$AJWBE046 + data$AJWBE047 + data$AJWBE048 + data$AJWBE049)/data$AJWBE001 
#7
data$percent_white_alone = 100*data$AJWNE002/data$AJWNE001 
#8
data$percent_black_alone = 100*data$AJWNE003/data$AJWNE001 
#9
data$percent_asian_alone = 100*data$AJWNE005/data$AJWNE001 
#10
data$percent_other_race_alone = 100*(data$AJWNE004 + data$AJWNE006 + data$AJWNE007)/data$AJWNE001 
#11
data$percent_multi_race = 100*data$AJWNE008/data$AJWNE001 
#12
data$percent_hispanic = 100*data$AJWVE012/data$AJWVE001 
#13
data$percent_family = 100*data$AJXKE002/data$AJXKE001 
#14
data$percent_living_alone = 100*data$AJXKE008/data$AJXKE001 
#15
data$percent_nonfamily_not_alone = 100*data$AJXKE009/data$AJXKE001 
#16
data$percent_HS_diploma_or_higher = 100*(data$AJYPE017 + data$AJYPE018 + data$AJYPE019 + data$AJYPE020 + data$AJYPE021 + data$AJYPE022 + data$AJYPE023 + data$AJYPE024 + data$AJYPE025)/data$AJYPE001 
#17
data$percent_some_college_or_higher = 100*(data$AJYPE019 + data$AJYPE020 + data$AJYPE021 + data$AJYPE022 + data$AJYPE023 + data$AJYPE024 + data$AJYPE025)/data$AJYPE001 
#18
data$percent_bachelors_degree_or_higher = 100*(data$AJYPE022 + data$AJYPE023 + data$AJYPE024 + data$AJYPE025)/data$AJYPE001 
#19
data$percent_graduate_degree = 100*(data$AJYPE023 + data$AJYPE024 + data$AJYPE025)/data$AJYPE001 
#20
data$percent_under_0.5_IPL = 100*data$AJY4E002/data$AJY4E001 
#21
data$percent_0.5to0.99_IPL = 100*data$AJY4E003/data$AJY4E001 
#22
data$percent_1to1.24_IPL = 100*data$AJY4E004/data$AJY4E001 
#23
data$percent_1.25to1.49_IPL = 100*data$AJY4E005/data$AJY4E001 
#24
data$percent_1.5to1.84_IPL = 100*data$AJY4E006/data$AJY4E001 
#25
data$percent_1.85to1.99_IPL = 100*data$AJY4E007/data$AJY4E001 
#26
data$percent_over_2_IPL = 100*data$AJY4E008/data$AJY4E001 
#27
data$median_household_income= data$AJZAE001
#28
data$percent_w_public_assist_income = 100*data$AJZUE002/data$AJZUE001 
#29
data$percent_in_labor_force = 100*data$AJ1CE002/data$AJ1CE001 
#30
data$percent_ue_in_labor_force = 100*data$AJ1CE005/data$AJ1CE001 
#31
data$num_housing_units = data$AJ1SE001
#32
data$percent_vacant = 100*data$AJ1TE003/data$AJ1TE001 
#33
data$median_year_built = data$AJ2NE001
#34
data$percent_no_health_insur = 100*(data$AJ35E017+ data$AJ35E033 + data$AJ35E050 + data$AJ35E066)/data$AJ35E001 
#35
data$percent_employer_only = 100*(data$AJ35E004 + data$AJ35E020 + data$AJ35E036 + data$AJ35E053)/data$AJ35E001 
#36
data$percent_direct_purchase_only = 100*(data$AJ35E005 + data$AJ35E021 + data$AJ35E037 + data$AJ35E054)/data$AJ35E001 
#37
data$percent_medicare_only = 100*(data$AJ35E006 + data$AJ35E022 + data$AJ35E038 + data$AJ35E055)/data$AJ35E001 
#38
data$percent_medicaid_only = 100*(data$AJ35E007 + data$AJ35E023 + data$AJ35E039)/data$AJ35E001 
#39
data$percent_tricare_only = 100*(data$AJ35E008 + data$AJ35E024 + data$AJ35E040 + data$AJ35E056)/data$AJ35E001 
#40
data$percent_VA_only = 100*(data$AJ35E009 + data$AJ35E025 + data$AJ35E041 + data$AJ35E057)/data$AJ35E001 
#41
data$percent_combo_health_insur = 100*(data$AJ35E010 + data$AJ35E026 + data$AJ35E042 + data$AJ35E058)/data$AJ35E001 
#42
data$percent_renter_occ = 100*(data$AJ18E010)/data$AJ18E001 
#43
data$percent_1_person_hh = 100*(data$AJ18E003 + data$AJ18E011)/data$AJ18E001 
#44
data$percent_2_person_hh = 100*(data$AJ18E004 + data$AJ18E012)/data$AJ18E001 
#45
data$percent_3_person_hh = 100*(data$AJ18E005 + data$AJ18E013)/data$AJ18E001 
#46
data$percent_4_person_hh = 100*(data$AJ18E006 + data$AJ18E014)/data$AJ18E001 
#47
data$percent_5_person_hh = 100*(data$AJ18E007 + data$AJ18E015)/data$AJ18E001 
#48
data$percent_6_person_hh = 100*(data$AJ18E008 + data$AJ18E016)/data$AJ18E001 
#49
data$percent_7ormore_person_hh = 100*(data$AJ18E009 + data$AJ18E017)/data$AJ18E001 
#50
data$percent_under0.5_per_room = 100*(data$AJ2AE003 + data$AJ2AE009)/data$AJ2AE001 
#51
data$percent_0.5to1_per_room = 100*(data$AJ2AE004 + data$AJ2AE010)/data$AJ2AE001 
#52
data$percent_1.01to1.5_per_room = 100*(data$AJ2AE005 + data$AJ2AE011)/data$AJ2AE001 
#53
data$percent_1.51to2_per_room = 100*(data$AJ2AE006 + data$AJ2AE012)/data$AJ2AE001 
#54
data$percent_2.01ormore_per_room = 100*(data$AJ2AE007 + data$AJ2AE013)/data$AJ2AE001 
#55
data$median_age = data$AJWCE001
#56
data$percent_walk_or_bike_to_work = 100*(data$AJXCE018 + data$AJXCE019)/data$AJXCE001
#57
data$percent_public_transpo_to_work = 100*(data$AJXCE010)/data$AJXCE001
#58
data$percent_drive_to_work = 100*data$AJXCE002/data$AJXCE001
#59
data$percent_leave_for_work_before_6am = 100*(data$AJXDE002 + data$AJXDE003 + data$AJXDE004)/data$AJXDE001
#60
data$percent_leave_for_work_6to9am = 100*(data$AJXDE005 + data$AJXDE006 + data$AJXDE007 + data$AJXDE008 + data$AJXDE009 + data$AJXDE010)/data$AJXDE001
#61
data$percent_leave_for_work_12to4pm = 100*data$AJXDE014/data$AJXDE001
#62
data$percent_leave_for_work_4tomidnight = 100*data$AJXDE015/data$AJXDE001
#63
data$percent_under5min_commute = 100*data$AJXEE002/data$AJXEE001
#64
data$percent_5to14min_commute = 100*(data$AJXEE003+data$AJXEE004)/data$AJXEE001
#65
data$percent_15to24min_commute = 100*(data$AJXEE005+data$AJXEE006)/data$AJXEE001
#66
data$percent_25to34min_commute = 100*(data$AJXEE007+data$AJXEE008)/data$AJXEE001
#67
data$percent_35to44min_commute = 100*(data$AJXEE009+data$AJXEE010)/data$AJXEE001
#68
data$percent_45to59min_commute = 100*(data$AJXEE011)/data$AJXEE001
#69
data$percent_60to89min_commute = 100*(data$AJXEE012)/data$AJXEE001
#70
data$percent_over90min_commute = 100*data$AJXEE013/data$AJXEE001

# %%
#median I:PL ?
#median occupancy ?

# %%
final_cols = c('GISJOIN', 'STATE', 'COUNTY', 'TRACTA','total_pop', 'percent_male', 'percent_0to19_years', 'percent_20to39_years', 'percent_40to64_years', 'percent_65andover', 'percent_white_alone', 'percent_black_alone', 'percent_asian_alone', 'percent_other_race_alone', 'percent_multi_race', 'percent_hispanic', 'percent_family', 'percent_living_alone', 'percent_nonfamily_not_alone', 'percent_HS_diploma_or_higher', 'percent_some_college_or_higher', 'percent_bachelors_degree_or_higher', 'percent_graduate_degree', 'percent_under_0.5_IPL', 'percent_0.5to0.99_IPL', 'percent_1to1.24_IPL', 'percent_1.25to1.49_IPL', 'percent_1.5to1.84_IPL', 'percent_1.85to1.99_IPL', 'percent_over_2_IPL', 'median_household_income', 'percent_w_public_assist_income', 'percent_in_labor_force', 'percent_ue_in_labor_force', 'num_housing_units', 'percent_vacant', 'median_year_built', 'percent_no_health_insur', 'percent_employer_only', 'percent_direct_purchase_only', 'percent_medicare_only', 'percent_medicaid_only', 'percent_tricare_only', 'percent_VA_only', 'percent_combo_health_insur', 'percent_renter_occ', 'percent_1_person_hh', 'percent_2_person_hh', 'percent_3_person_hh', 'percent_4_person_hh', 'percent_5_person_hh', 'percent_6_person_hh', 'percent_7ormore_person_hh', 'percent_under0.5_per_room', 'percent_0.5to1_per_room', 'percent_1.01to1.5_per_room', 'percent_1.51to2_per_room', 'percent_2.01ormore_per_room', 'id', 'group', 'agency', 'nfirs_group_final', 'nfirs_category_final', 'nfirs_code_final', 'occurred_on', 'day', 'month', 'year', 'hour_of_day', 'day_of_week', 'day_of_month', 'day_of_year', 'month_of_year', 'zip_code_lookup', 'tract_block_group_centroid_lat', 'tract_block_group_centroid_lng',  
'median_age', 'percent_walk_or_bike_to_work', 'percent_public_transpo_to_work', 'percent_drive_to_work', 'percent_leave_for_work_before_6am', 'percent_leave_for_work_6to9am', 'percent_leave_for_work_12to4pm', 'percent_leave_for_work_4tomidnight', 'percent_under5min_commute',
'percent_5to14min_commute',
'percent_15to24min_commute',
'percent_25to34min_commute',
'percent_35to44min_commute',
'percent_45to59min_commute',
'percent_60to89min_commute',
'percent_over90min_commute', 'incident_id', 'alternate_id'
)
data2 <- subset(data, select = final_cols)
dim(data2)
# Out:
# [1] 1400118      94

# %%
#setwd('/data_source')
write.csv(data2, "clean_columns_everything.csv")
